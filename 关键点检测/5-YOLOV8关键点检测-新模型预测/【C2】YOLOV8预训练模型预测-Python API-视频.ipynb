# %% [markdown]
# # YOLOV8预训练模型预测-Python API-视频
#
# 同济子豪兄：https://space.bilibili.com/1900783

# %% [markdown]
# ## 导入工具包

# %%
import cv2
import numpy as np
import time
from tqdm import tqdm

from ultralytics import YOLO

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 载入模型

# %%
# model = YOLO('checkpoint/Triangle_215_yolov8n_pose_pretrain.pt')
model = YOLO('checkpoint/Triangle_215_yolov8x_pose_p6_pretrain.pt')

# %% [markdown]
# ## 可视化配置

# %%
# 框（rectangle）可视化配置
bbox_color = (150, 0, 0)             # 框的 BGR 颜色
bbox_thickness = 2                   # 框的线宽

# 框类别文字
bbox_labelstr = {
    'font_size':1,         # 字体大小
    'font_thickness':2,    # 字体粗细
    'offset_x':0,          # X 方向，文字偏移距离，向右为正
    'offset_y':-10,        # Y 方向，文字偏移距离，向下为正
}

# %%
# 关键点 BGR 配色
kpt_color_map = {
    0:{'name':'angle_30', 'color':[255, 0, 0], 'radius':6},      # 30度角点
    1:{'name':'angle_60', 'color':[0, 255, 0], 'radius':6},      # 60度角点
    2:{'name':'angle_90', 'color':[0, 0, 255], 'radius':6},      # 90度角点
}

# 骨架连接 BGR 配色
skeleton_map = [
    {'srt_kpt_id':0, 'dst_kpt_id':1, 'color':[196, 75, 255], 'thickness':2},        # 30度角点-60度角点
    {'srt_kpt_id':0, 'dst_kpt_id':2, 'color':[180, 187, 28], 'thickness':2},        # 30度角点-90度角点
    {'srt_kpt_id':1, 'dst_kpt_id':2, 'color':[47,255, 173], 'thickness':2},         # 60度角点-90度角点
]

# %% [markdown]
# ## 逐帧处理函数

# %%
def process_frame(img_bgr):
    
    '''
    输入摄像头画面 bgr-array，输出图像 bgr-array
    '''
    
    results = model(img_bgr)
    
    # 预测框的个数
    num_bbox = len(results[0].boxes.cls)
    
    # 预测框的 xyxy 坐标
    bboxes_xyxy = results[0].boxes.xyxy.cpu().numpy().astype('uint32') 
    
    # 关键点的 xy 坐标
    bboxes_keypoints = results[0].keypoints.cpu().numpy().astype('uint32')
    
    for idx in range(num_bbox): # 遍历每个框

        # 获取该框坐标
        bbox_xyxy = bboxes_xyxy[idx] 

        # 获取框的预测类别（对于关键点检测，只有一个类别）
        bbox_label = results[0].names[0]

        # 画框
        img_bgr = cv2.rectangle(img_bgr, (bbox_xyxy[0], bbox_xyxy[1]), (bbox_xyxy[2], bbox_xyxy[3]), bbox_color, bbox_thickness)

        # 写框类别文字：图片，文字字符串，文字左上角坐标，字体，字体大小，颜色，字体粗细
        img_bgr = cv2.putText(img_bgr, bbox_label, (bbox_xyxy[0]+bbox_labelstr['offset_x'], bbox_xyxy[1]+bbox_labelstr['offset_y']), cv2.FONT_HERSHEY_SIMPLEX, bbox_labelstr['font_size'], bbox_color, bbox_labelstr['font_thickness'])

        bbox_keypoints = bboxes_keypoints[idx] # 该框所有关键点坐标和置信度

        # 画该框的骨架连接
        for skeleton in skeleton_map:

            # 获取起始点坐标
            srt_kpt_id = skeleton['srt_kpt_id']
            srt_kpt_x = bbox_keypoints[srt_kpt_id][0]
            srt_kpt_y = bbox_keypoints[srt_kpt_id][1]

            # 获取终止点坐标
            dst_kpt_id = skeleton['dst_kpt_id']
            dst_kpt_x = bbox_keypoints[dst_kpt_id][0]
            dst_kpt_y = bbox_keypoints[dst_kpt_id][1]

            # 获取骨架连接颜色
            skeleton_color = skeleton['color']

            # 获取骨架连接线宽
            skeleton_thickness = skeleton['thickness']

            # 画骨架连接
            img_bgr = cv2.line(img_bgr, (srt_kpt_x, srt_kpt_y),(dst_kpt_x, dst_kpt_y),color=skeleton_color,thickness=skeleton_thickness)

        # 画该框的关键点
        for kpt_id in kpt_color_map:
            kpt_color = kpt_color_map[kpt_id]['color']
            kpt_radius = kpt_color_map[kpt_id]['radius']
            kpt_x = bbox_keypoints[kpt_id][0]
            kpt_y = bbox_keypoints[kpt_id][1]
            img_bgr = cv2.circle(img_bgr, (kpt_x, kpt_y), kpt_radius, kpt_color, -1)
    
    return img_bgr

# %% [markdown]
# ## 视频逐帧处理（模板）

# %%
# 视频逐帧处理代码模板
# 不需修改任何代码，只需定义process_frame函数即可
# 同济子豪兄 2021-7-10

def generate_video(input_path='videos/robot.mp4'):
    filehead = input_path.split('/')[-1]
    output_path = "out-" + filehead
    
    print('视频开始处理',input_path)
    
    # 获取视频总帧数
    cap = cv2.VideoCapture(input_path)
    frame_count = 0
    while(cap.isOpened()):
        success, frame = cap.read()
        frame_count += 1
        if not success:
            break
    cap.release()
    print('视频总帧数为',frame_count)
    
    # cv2.namedWindow('Crack Detection and Measurement Video Processing')
    cap = cv2.VideoCapture(input_path)
    frame_size = (cap.get(cv2.CAP_PROP_FRAME_WIDTH), cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # fourcc = int(cap.get(cv2.CAP_PROP_FOURCC))
    # fourcc = cv2.VideoWriter_fourcc(*'XVID')
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = cap.get(cv2.CAP_PROP_FPS)

    out = cv2.VideoWriter(output_path, fourcc, fps, (int(frame_size[0]), int(frame_size[1])))
    
    # 进度条绑定视频总帧数
    with tqdm(total=frame_count-1) as pbar:
        try:
            while(cap.isOpened()):
                success, frame = cap.read()
                if not success:
                    break

                # 处理帧
                # frame_path = './temp_frame.png'
                # cv2.imwrite(frame_path, frame)
                try:
                    frame = process_frame(frame)
                except Exception as error:
                    print('报错！', error)
                    pass
                
                if success == True:
                    # cv2.imshow('Video Processing', frame)
                    out.write(frame)

                    # 进度条更新一帧
                    pbar.update(1)

                # if cv2.waitKey(1) & 0xFF == ord('q'):
                    # break
        except:
            print('中途中断')
            pass

    cv2.destroyAllWindows()
    out.release()
    cap.release()
    print('视频已保存', output_path)

# %% [markdown]
# ## 视频预测

# %%
generate_video(input_path='videos/triangle_7.mp4')
# Out:
# 视频开始处理 videos/triangle_7.mp4
# 视频总帧数为 220
#   0%|          | 0/219 [00:00<?, ?it/s]
# 0: 768x1280 2 sjb_rects, 48.2ms
# Speed: 1.0ms preprocess, 48.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#   1%|          | 2/219 [00:00<00:15, 13.84it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.5ms
# Speed: 0.9ms preprocess, 47.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#   2%|▏         | 4/219 [00:00<00:14, 14.40it/s]
# 0: 768x1280 2 sjb_rects, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#   3%|▎         | 6/219 [00:00<00:14, 14.78it/s]
# 0: 768x1280 2 sjb_rects, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   4%|▎         | 8/219 [00:00<00:14, 14.92it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   5%|▍         | 10/219 [00:00<00:14, 14.83it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#   5%|▌         | 12/219 [00:00<00:13, 14.87it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   6%|▋         | 14/219 [00:00<00:13, 14.91it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   7%|▋         | 16/219 [00:01<00:13, 14.84it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#   8%|▊         | 18/219 [00:01<00:13, 14.92it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#   9%|▉         | 20/219 [00:01<00:13, 14.92it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  10%|█         | 22/219 [00:01<00:13, 14.79it/s]
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  11%|█         | 24/219 [00:01<00:13, 14.86it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  12%|█▏        | 26/219 [00:01<00:12, 14.92it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  13%|█▎        | 28/219 [00:01<00:12, 14.81it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  14%|█▎        | 30/219 [00:02<00:12, 14.74it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  15%|█▍        | 32/219 [00:02<00:12, 14.76it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  16%|█▌        | 34/219 [00:02<00:12, 14.70it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  16%|█▋        | 36/219 [00:02<00:12, 14.66it/s]
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  17%|█▋        | 38/219 [00:02<00:12, 14.75it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  18%|█▊        | 40/219 [00:02<00:12, 14.76it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  19%|█▉        | 42/219 [00:02<00:11, 14.86it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  20%|██        | 44/219 [00:02<00:11, 14.98it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  21%|██        | 46/219 [00:03<00:11, 14.89it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  22%|██▏       | 48/219 [00:03<00:11, 14.85it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  23%|██▎       | 50/219 [00:03<00:11, 14.91it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  24%|██▎       | 52/219 [00:03<00:11, 14.52it/s]
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  25%|██▍       | 54/219 [00:03<00:11, 14.29it/s]
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.1ms
# Speed: 1.2ms preprocess, 48.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  26%|██▌       | 56/219 [00:03<00:11, 14.10it/s]
# 0: 768x1280 3 sjb_rects, 48.0ms
# Speed: 1.0ms preprocess, 48.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  26%|██▋       | 58/219 [00:03<00:11, 14.17it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.2ms
# Speed: 1.2ms preprocess, 48.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  27%|██▋       | 60/219 [00:04<00:11, 14.19it/s]
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  28%|██▊       | 62/219 [00:04<00:10, 14.42it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 6.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  29%|██▉       | 64/219 [00:04<00:10, 14.20it/s]
# 0: 768x1280 3 sjb_rects, 48.0ms
# Speed: 0.9ms preprocess, 48.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.0ms
# Speed: 0.9ms preprocess, 48.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  30%|███       | 66/219 [00:04<00:10, 14.21it/s]
# 0: 768x1280 3 sjb_rects, 56.0ms
# Speed: 1.3ms preprocess, 56.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.2ms
# Speed: 0.9ms preprocess, 48.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  31%|███       | 68/219 [00:04<00:10, 13.80it/s]
# 0: 768x1280 3 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  32%|███▏      | 70/219 [00:04<00:10, 13.93it/s]
# 0: 768x1280 3 sjb_rects, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  33%|███▎      | 72/219 [00:04<00:10, 14.11it/s]
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  34%|███▍      | 74/219 [00:05<00:10, 14.17it/s]
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 2.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  35%|███▍      | 76/219 [00:05<00:10, 14.03it/s]
# 0: 768x1280 3 sjb_rects, 48.2ms
# Speed: 1.0ms preprocess, 48.2ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  36%|███▌      | 78/219 [00:05<00:10, 13.84it/s]
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.2ms
# Speed: 0.9ms preprocess, 48.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#  37%|███▋      | 80/219 [00:05<00:09, 13.96it/s]
# 0: 768x1280 2 sjb_rects, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  37%|███▋      | 82/219 [00:05<00:09, 13.89it/s]
# 0: 768x1280 2 sjb_rects, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  38%|███▊      | 84/219 [00:05<00:09, 13.57it/s]
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  39%|███▉      | 86/219 [00:05<00:09, 13.52it/s]
# 0: 768x1280 2 sjb_rects, 50.6ms
# Speed: 0.9ms preprocess, 50.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 52.0ms
# Speed: 0.9ms preprocess, 52.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  40%|████      | 88/219 [00:06<00:09, 13.60it/s]
# 0: 768x1280 2 sjb_rects, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  41%|████      | 90/219 [00:06<00:09, 13.49it/s]
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 2.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  42%|████▏     | 92/219 [00:06<00:09, 13.47it/s]
# 0: 768x1280 2 sjb_rects, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 2.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 52.5ms
# Speed: 0.9ms preprocess, 52.5ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#  43%|████▎     | 94/219 [00:06<00:09, 13.49it/s]
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.3ms
# Speed: 1.1ms preprocess, 50.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#  44%|████▍     | 96/219 [00:06<00:09, 13.33it/s]
# 0: 768x1280 2 sjb_rects, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.5ms
# Speed: 0.8ms preprocess, 50.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  45%|████▍     | 98/219 [00:06<00:08, 13.59it/s]
# 0: 768x1280 2 sjb_rects, 51.8ms
# Speed: 0.9ms preprocess, 51.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#  46%|████▌     | 100/219 [00:07<00:08, 13.50it/s]
# 0: 768x1280 2 sjb_rects, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  47%|████▋     | 102/219 [00:07<00:08, 13.39it/s]
# 0: 768x1280 2 sjb_rects, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  47%|████▋     | 104/219 [00:07<00:08, 13.45it/s]
# 0: 768x1280 2 sjb_rects, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  48%|████▊     | 106/219 [00:07<00:08, 13.53it/s]
# 0: 768x1280 2 sjb_rects, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.7ms
# Speed: 0.9ms preprocess, 48.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#  49%|████▉     | 108/219 [00:07<00:08, 13.54it/s]
# 0: 768x1280 2 sjb_rects, 51.6ms
# Speed: 0.9ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 0.9ms preprocess, 50.1ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#  50%|█████     | 110/219 [00:07<00:08, 13.53it/s]
# 0: 768x1280 2 sjb_rects, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  51%|█████     | 112/219 [00:07<00:07, 13.62it/s]
# 0: 768x1280 1 sjb_rect, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 50.3ms
# Speed: 0.9ms preprocess, 50.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  52%|█████▏    | 114/219 [00:08<00:07, 13.54it/s]
# 0: 768x1280 1 sjb_rect, 48.9ms
# Speed: 1.0ms preprocess, 48.9ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  53%|█████▎    | 116/219 [00:08<00:07, 13.42it/s]
# 0: 768x1280 1 sjb_rect, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 50.4ms
# Speed: 0.9ms preprocess, 50.4ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  54%|█████▍    | 118/219 [00:08<00:07, 13.68it/s]
# 0: 768x1280 1 sjb_rect, 48.3ms
# Speed: 0.9ms preprocess, 48.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  55%|█████▍    | 120/219 [00:08<00:07, 13.90it/s]
# 0: 768x1280 1 sjb_rect, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 50.4ms
# Speed: 0.9ms preprocess, 50.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#  56%|█████▌    | 122/219 [00:08<00:07, 13.62it/s]
# 0: 768x1280 1 sjb_rect, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.3ms
# Speed: 0.9ms preprocess, 49.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#  57%|█████▋    | 124/219 [00:08<00:07, 13.51it/s]
# 0: 768x1280 2 sjb_rects, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  58%|█████▊    | 126/219 [00:08<00:06, 13.39it/s]
# 0: 768x1280 1 sjb_rect, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 52.4ms
# Speed: 0.9ms preprocess, 52.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  58%|█████▊    | 128/219 [00:09<00:06, 13.59it/s]
# 0: 768x1280 2 sjb_rects, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 50.5ms
# Speed: 0.9ms preprocess, 50.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  59%|█████▉    | 130/219 [00:09<00:06, 13.80it/s]
# 0: 768x1280 1 sjb_rect, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  60%|██████    | 132/219 [00:09<00:06, 13.72it/s]
# 0: 768x1280 1 sjb_rect, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 51.1ms
# Speed: 0.9ms preprocess, 51.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  61%|██████    | 134/219 [00:09<00:06, 13.94it/s]
# 0: 768x1280 2 sjb_rects, 50.2ms
# Speed: 0.9ms preprocess, 50.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  62%|██████▏   | 136/219 [00:09<00:05, 14.05it/s]
# 0: 768x1280 2 sjb_rects, 49.7ms
# Speed: 0.9ms preprocess, 49.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  63%|██████▎   | 138/219 [00:09<00:05, 13.84it/s]
# 0: 768x1280 2 sjb_rects, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  64%|██████▍   | 140/219 [00:09<00:05, 13.95it/s]
# 0: 768x1280 2 sjb_rects, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  65%|██████▍   | 142/219 [00:10<00:05, 13.82it/s]
# 0: 768x1280 1 sjb_rect, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  66%|██████▌   | 144/219 [00:10<00:05, 13.72it/s]
# 0: 768x1280 1 sjb_rect, 50.2ms
# Speed: 0.9ms preprocess, 50.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 sjb_rect, 51.4ms
# Speed: 1.3ms preprocess, 51.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  67%|██████▋   | 146/219 [00:10<00:05, 13.47it/s]
# 0: 768x1280 2 sjb_rects, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.6ms
# Speed: 1.3ms preprocess, 50.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  68%|██████▊   | 148/219 [00:10<00:05, 13.46it/s]
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 0.9ms preprocess, 50.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.7ms
# Speed: 0.9ms preprocess, 50.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  68%|██████▊   | 150/219 [00:10<00:05, 13.54it/s]
# 0: 768x1280 2 sjb_rects, 48.5ms
# Speed: 0.9ms preprocess, 48.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  69%|██████▉   | 152/219 [00:10<00:04, 13.71it/s]
# 0: 768x1280 2 sjb_rects, 49.0ms
# Speed: 0.9ms preprocess, 49.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  70%|███████   | 154/219 [00:10<00:04, 13.99it/s]
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 0.9ms preprocess, 50.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  71%|███████   | 156/219 [00:11<00:04, 13.50it/s]
# 0: 768x1280 2 sjb_rects, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.3ms
# Speed: 0.9ms preprocess, 49.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  72%|███████▏  | 158/219 [00:11<00:04, 13.77it/s]
# 0: 768x1280 2 sjb_rects, 49.0ms
# Speed: 0.9ms preprocess, 49.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.9ms
# Speed: 0.9ms preprocess, 50.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  73%|███████▎  | 160/219 [00:11<00:04, 14.03it/s]
# 0: 768x1280 2 sjb_rects, 51.4ms
# Speed: 0.9ms preprocess, 51.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 51.8ms
# Speed: 0.8ms preprocess, 51.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  74%|███████▍  | 162/219 [00:11<00:04, 13.99it/s]
# 0: 768x1280 2 sjb_rects, 50.2ms
# Speed: 0.9ms preprocess, 50.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  75%|███████▍  | 164/219 [00:11<00:03, 14.05it/s]
# 0: 768x1280 2 sjb_rects, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  76%|███████▌  | 166/219 [00:11<00:03, 14.25it/s]
# 0: 768x1280 2 sjb_rects, 48.3ms
# Speed: 0.9ms preprocess, 48.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  77%|███████▋  | 168/219 [00:11<00:03, 14.17it/s]
# 0: 768x1280 2 sjb_rects, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.2ms
# Speed: 0.9ms preprocess, 50.2ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#  78%|███████▊  | 170/219 [00:12<00:03, 14.05it/s]
# 0: 768x1280 2 sjb_rects, 48.3ms
# Speed: 1.3ms preprocess, 48.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 52.6ms
# Speed: 1.1ms preprocess, 52.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  79%|███████▊  | 172/219 [00:12<00:03, 13.54it/s]
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 1.3ms preprocess, 48.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  79%|███████▉  | 174/219 [00:12<00:03, 13.66it/s]
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 1.0ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  80%|████████  | 176/219 [00:12<00:03, 13.94it/s]
# 0: 768x1280 2 sjb_rects, 52.3ms
# Speed: 0.9ms preprocess, 52.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 51.1ms
# Speed: 1.3ms preprocess, 51.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  81%|████████▏ | 178/219 [00:12<00:02, 13.80it/s]
# 0: 768x1280 2 sjb_rects, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  82%|████████▏ | 180/219 [00:12<00:02, 13.67it/s]
# 0: 768x1280 2 sjb_rects, 48.4ms
# Speed: 1.0ms preprocess, 48.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  83%|████████▎ | 182/219 [00:12<00:02, 13.87it/s]
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 1.1ms preprocess, 48.1ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#  84%|████████▍ | 184/219 [00:13<00:02, 13.98it/s]
# 0: 768x1280 2 sjb_rects, 48.0ms
# Speed: 0.8ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.7ms preprocess, 48.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  85%|████████▍ | 186/219 [00:13<00:02, 14.08it/s]
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.8ms preprocess, 47.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.8ms preprocess, 47.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#  86%|████████▌ | 188/219 [00:13<00:02, 14.22it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.2ms
# Speed: 0.8ms preprocess, 48.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#  87%|████████▋ | 190/219 [00:13<00:02, 14.08it/s]
# 0: 768x1280 2 sjb_rects, 48.3ms
# Speed: 0.8ms preprocess, 48.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.2ms
# Speed: 0.9ms preprocess, 48.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  88%|████████▊ | 192/219 [00:13<00:01, 14.05it/s]
# 0: 768x1280 2 sjb_rects, 48.2ms
# Speed: 0.8ms preprocess, 48.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 0.8ms preprocess, 47.9ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  89%|████████▊ | 194/219 [00:13<00:01, 14.12it/s]
# 0: 768x1280 3 sjb_rects, 48.2ms
# Speed: 0.8ms preprocess, 48.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 3 sjb_rects, 48.1ms
# Speed: 1.3ms preprocess, 48.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  89%|████████▉ | 196/219 [00:13<00:01, 13.83it/s]
# 0: 768x1280 3 sjb_rects, 47.9ms
# Speed: 1.0ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  90%|█████████ | 198/219 [00:14<00:01, 14.07it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  91%|█████████▏| 200/219 [00:14<00:01, 14.23it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.4ms
# Speed: 0.9ms preprocess, 48.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  92%|█████████▏| 202/219 [00:14<00:01, 14.53it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  93%|█████████▎| 204/219 [00:14<00:01, 14.71it/s]
# 0: 768x1280 2 sjb_rects, 48.0ms
# Speed: 1.2ms preprocess, 48.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  94%|█████████▍| 206/219 [00:14<00:00, 14.47it/s]
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  95%|█████████▍| 208/219 [00:14<00:00, 14.39it/s]
# 0: 768x1280 2 sjb_rects, 48.1ms
# Speed: 1.2ms preprocess, 48.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  96%|█████████▌| 210/219 [00:14<00:00, 14.50it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#  97%|█████████▋| 212/219 [00:15<00:00, 14.38it/s]
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 1.0ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  98%|█████████▊| 214/219 [00:15<00:00, 14.50it/s]
# 0: 768x1280 2 sjb_rects, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  99%|█████████▊| 216/219 [00:15<00:00, 14.59it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
# 100%|█████████▉| 218/219 [00:15<00:00, 14.64it/s]
# 0: 768x1280 2 sjb_rects, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
# 100%|██████████| 219/219 [00:15<00:00, 14.09it/s]
# 视频已保存 out-triangle_7.mp4
