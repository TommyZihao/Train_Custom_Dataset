# %% [markdown]
# # YOLOV8关键点检测预测-命令行-摄像头实时画面
#
# 同济子豪兄 2023-4-15

# %% [markdown]
# ## `注意，本代码需要在本地，连接摄像头运行，不能在云GPU平台运行`

# %% [markdown]
# ## 安装YOLOV8

# %%
# !pip install ultralytics --upgrade -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 安装其它第三方工具包

# %%
# !pip install numpy opencv-python pillow pandas matplotlib seaborn tqdm -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 下载训练得到的模型权重文件

# %%
# yolov8n-pose 预训练模型微调
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/checkpoint/Triangle_215_yolov8n_pose_pretrain.pt -P checkpoint

# yolo8x-pose-p6 预训练模型微调
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/checkpoint/Triangle_215_yolov8x_pose_p6_pretrain.pt -P checkpoint

# %% [markdown]
# ## 验证安装成功

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.87 🚀 Python-3.7.2 torch-1.13.1 CPU
# Setup complete ✅ (16 CPUs, 16.0 GB RAM, 918.5/931.5 GB disk)

# %% [markdown]
# ## 命令行预测

# %%
# !yolo pose predict model=checkpoint/Triangle_215_yolov8n_pose_pretrain.pt source=0 show
# Out:
# 2023-04-27 19:02:54.416 Python[15512:4016173] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/ly/mdyk3b_d1r39hm00y4s1yk1m0000gn/T/org.python.python.savedState
# Ultralytics YOLOv8.0.87 🚀 Python-3.7.2 torch-1.13.1 CPU
# YOLOv8n-pose summary (fused): 187 layers, 3077822 parameters, 0 gradients, 8.3 GFLOPs
#
# 1/1: 0... Success ✅ (inf frames of shape 1280x720 at 1.00 FPS)
#
# HTTPSConnectionPool(host='www.google-analytics.com', port=443): Max retries exceeded with url: /mp/collect?measurement_id=G-X8NCJYTQXM&api_secret=QLQrATrNSwGRFRLE-cbHJw (Caused by ProxyError('Cannot connect to proxy.', OSError(0, 'Error')))
# 0: 384x640 2 sjb_rects, 141.7ms
# 0: 384x640 2 sjb_rects, 101.3ms
# 0: 384x640 1 sjb_rect, 100.5ms
# 0: 384x640 1 sjb_rect, 98.3ms
# 0: 384x640 1 sjb_rect, 102.5ms
# 0: 384x640 (no detections), 104.4ms
# 0: 384x640 (no detections), 104.3ms
# 0: 384x640 (no detections), 100.6ms
# 0: 384x640 (no detections), 103.0ms
# ...

# %% [markdown]
# ## 按`q`键退出
