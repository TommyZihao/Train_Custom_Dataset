# %% [markdown]
# # 安装YOLOV8
#
# 同济子豪兄 2023-4-15
#
# 安装YOLOV8环境和所需的第三方工具包

# %% [markdown]
# ## 安装YOLOV8

# %%
# !pip install ultralytics --upgrade -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 验证安装成功

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.88 🚀 Python-3.7.2 torch-1.13.1 CPU
# Setup complete ✅ (16 CPUs, 16.0 GB RAM, 865.3/931.5 GB disk)

# %% [markdown]
# ## 安装其它第三方工具包

# %%
# !pip install numpy opencv-python pillow pandas matplotlib seaborn tqdm onnx onnxruntime -i https://pypi.tuna.tsinghua.edu.cn/simple
