# %% [markdown]
# # YOLOV8预训练模型预测-Python API-视频
#
# 同济子豪兄：https://space.bilibili.com/1900783

# %% [markdown]
# ## 导入工具包

# %%
import cv2
import numpy as np
import time
from tqdm import tqdm

from ultralytics import YOLO

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 载入模型

# %%
# 载入预训练模型
# model = YOLO('yolov8n-pose.pt')
# model = YOLO('yolov8s-pose.pt')
# model = YOLO('yolov8m-pose.pt')
# model = YOLO('yolov8l-pose.pt')
# model = YOLO('yolov8x-pose.pt')
model = YOLO('yolov8x-pose-p6.pt')

# %% [markdown]
# ## 可视化配置

# %%
# 框（rectangle）可视化配置
bbox_color = (150, 0, 0)             # 框的 BGR 颜色
bbox_thickness = 2                   # 框的线宽

# 框类别文字
bbox_labelstr = {
    'font_size':1,         # 字体大小
    'font_thickness':2,   # 字体粗细
    'offset_x':0,          # X 方向，文字偏移距离，向右为正
    'offset_y':-10,       # Y 方向，文字偏移距离，向下为正
}

# %%
# 关键点 BGR 配色
kpt_color_map = {
    0:{'name':'Nose', 'color':[0, 0, 255], 'radius':6},                # 鼻尖
    1:{'name':'Right Eye', 'color':[255, 0, 0], 'radius':6},           # 右边眼睛
    2:{'name':'Left Eye', 'color':[255, 0, 0], 'radius':6},            # 左边眼睛
    3:{'name':'Right Ear', 'color':[0, 255, 0], 'radius':6},           # 右边耳朵
    4:{'name':'Left Ear', 'color':[0, 255, 0], 'radius':6},            # 左边耳朵
    5:{'name':'Right Shoulder', 'color':[193, 182, 255], 'radius':6},  # 右边肩膀
    6:{'name':'Left Shoulder', 'color':[193, 182, 255], 'radius':6},   # 左边肩膀
    7:{'name':'Right Elbow', 'color':[16, 144, 247], 'radius':6},      # 右侧胳膊肘
    8:{'name':'Left Elbow', 'color':[16, 144, 247], 'radius':6},       # 左侧胳膊肘
    9:{'name':'Right Wrist', 'color':[1, 240, 255], 'radius':6},       # 右侧手腕
    10:{'name':'Left Wrist', 'color':[1, 240, 255], 'radius':6},       # 左侧手腕
    11:{'name':'Right Hip', 'color':[140, 47, 240], 'radius':6},       # 右侧胯
    12:{'name':'Left Hip', 'color':[140, 47, 240], 'radius':6},        # 左侧胯
    13:{'name':'Right Knee', 'color':[223, 155, 60], 'radius':6},      # 右侧膝盖
    14:{'name':'Left Knee', 'color':[223, 155, 60], 'radius':6},       # 左侧膝盖
    15:{'name':'Right Ankle', 'color':[139, 0, 0], 'radius':6},        # 右侧脚踝
    16:{'name':'Left Ankle', 'color':[139, 0, 0], 'radius':6},         # 左侧脚踝
}

# 骨架连接 BGR 配色
skeleton_map = [
    {'srt_kpt_id':15, 'dst_kpt_id':13, 'color':[0, 100, 255], 'thickness':2},       # 右侧脚踝-右侧膝盖
    {'srt_kpt_id':13, 'dst_kpt_id':11, 'color':[0, 255, 0], 'thickness':2},         # 右侧膝盖-右侧胯
    {'srt_kpt_id':16, 'dst_kpt_id':14, 'color':[255, 0, 0], 'thickness':2},         # 左侧脚踝-左侧膝盖
    {'srt_kpt_id':14, 'dst_kpt_id':12, 'color':[0, 0, 255], 'thickness':2},         # 左侧膝盖-左侧胯
    {'srt_kpt_id':11, 'dst_kpt_id':12, 'color':[122, 160, 255], 'thickness':2},     # 右侧胯-左侧胯
    {'srt_kpt_id':5, 'dst_kpt_id':11, 'color':[139, 0, 139], 'thickness':2},        # 右边肩膀-右侧胯
    {'srt_kpt_id':6, 'dst_kpt_id':12, 'color':[237, 149, 100], 'thickness':2},      # 左边肩膀-左侧胯
    {'srt_kpt_id':5, 'dst_kpt_id':6, 'color':[152, 251, 152], 'thickness':2},       # 右边肩膀-左边肩膀
    {'srt_kpt_id':5, 'dst_kpt_id':7, 'color':[148, 0, 69], 'thickness':2},          # 右边肩膀-右侧胳膊肘
    {'srt_kpt_id':6, 'dst_kpt_id':8, 'color':[0, 75, 255], 'thickness':2},          # 左边肩膀-左侧胳膊肘
    {'srt_kpt_id':7, 'dst_kpt_id':9, 'color':[56, 230, 25], 'thickness':2},         # 右侧胳膊肘-右侧手腕
    {'srt_kpt_id':8, 'dst_kpt_id':10, 'color':[0,240, 240], 'thickness':2},         # 左侧胳膊肘-左侧手腕
    {'srt_kpt_id':1, 'dst_kpt_id':2, 'color':[224,255, 255], 'thickness':2},        # 右边眼睛-左边眼睛
    {'srt_kpt_id':0, 'dst_kpt_id':1, 'color':[47,255, 173], 'thickness':2},         # 鼻尖-左边眼睛
    {'srt_kpt_id':0, 'dst_kpt_id':2, 'color':[203,192,255], 'thickness':2},         # 鼻尖-左边眼睛
    {'srt_kpt_id':1, 'dst_kpt_id':3, 'color':[196, 75, 255], 'thickness':2},        # 右边眼睛-右边耳朵
    {'srt_kpt_id':2, 'dst_kpt_id':4, 'color':[86, 0, 25], 'thickness':2},           # 左边眼睛-左边耳朵
    {'srt_kpt_id':3, 'dst_kpt_id':5, 'color':[255,255, 0], 'thickness':2},          # 右边耳朵-右边肩膀
    {'srt_kpt_id':4, 'dst_kpt_id':6, 'color':[255, 18, 200], 'thickness':2}         # 左边耳朵-左边肩膀
]

# %% [markdown]
# ## 逐帧处理函数

# %%
def process_frame(img_bgr):
    
    '''
    输入摄像头画面 bgr-array，输出图像 bgr-array
    '''
    
    results = model(img_bgr)
    
    # 预测框的个数
    num_bbox = len(results[0].boxes.cls)
    
    # 预测框的 xyxy 坐标
    bboxes_xyxy = results[0].boxes.xyxy.cpu().numpy().astype('uint32') 
    
    # 关键点的 xy 坐标
    bboxes_keypoints = results[0].keypoints.cpu().numpy().astype('uint32')
    
    for idx in range(num_bbox): # 遍历每个框

        # 获取该框坐标
        bbox_xyxy = bboxes_xyxy[idx] 

        # 获取框的预测类别（对于关键点检测，只有一个类别）
        bbox_label = results[0].names[0]

        # 画框
        img_bgr = cv2.rectangle(img_bgr, (bbox_xyxy[0], bbox_xyxy[1]), (bbox_xyxy[2], bbox_xyxy[3]), bbox_color, bbox_thickness)

        # 写框类别文字：图片，文字字符串，文字左上角坐标，字体，字体大小，颜色，字体粗细
        img_bgr = cv2.putText(img_bgr, bbox_label, (bbox_xyxy[0]+bbox_labelstr['offset_x'], bbox_xyxy[1]+bbox_labelstr['offset_y']), cv2.FONT_HERSHEY_SIMPLEX, bbox_labelstr['font_size'], bbox_color, bbox_labelstr['font_thickness'])

        bbox_keypoints = bboxes_keypoints[idx] # 该框所有关键点坐标和置信度

        # 画该框的骨架连接
        for skeleton in skeleton_map:

            # 获取起始点坐标
            srt_kpt_id = skeleton['srt_kpt_id']
            srt_kpt_x = bbox_keypoints[srt_kpt_id][0]
            srt_kpt_y = bbox_keypoints[srt_kpt_id][1]

            # 获取终止点坐标
            dst_kpt_id = skeleton['dst_kpt_id']
            dst_kpt_x = bbox_keypoints[dst_kpt_id][0]
            dst_kpt_y = bbox_keypoints[dst_kpt_id][1]

            # 获取骨架连接颜色
            skeleton_color = skeleton['color']

            # 获取骨架连接线宽
            skeleton_thickness = skeleton['thickness']

            # 画骨架连接
            img_bgr = cv2.line(img_bgr, (srt_kpt_x, srt_kpt_y),(dst_kpt_x, dst_kpt_y),color=skeleton_color,thickness=skeleton_thickness)

        # 画该框的关键点
        for kpt_id in kpt_color_map:
            kpt_color = kpt_color_map[kpt_id]['color']
            kpt_radius = kpt_color_map[kpt_id]['radius']
            kpt_x = bbox_keypoints[kpt_id][0]
            kpt_y = bbox_keypoints[kpt_id][1]
            img_bgr = cv2.circle(img_bgr, (kpt_x, kpt_y), kpt_radius, kpt_color, -1)
    
    return img_bgr

# %% [markdown]
# ## 视频逐帧处理（模板）

# %%
# 视频逐帧处理代码模板
# 不需修改任何代码，只需定义process_frame函数即可
# 同济子豪兄 2021-7-10

def generate_video(input_path='videos/robot.mp4'):
    filehead = input_path.split('/')[-1]
    output_path = "out-" + filehead
    
    print('视频开始处理',input_path)
    
    # 获取视频总帧数
    cap = cv2.VideoCapture(input_path)
    frame_count = 0
    while(cap.isOpened()):
        success, frame = cap.read()
        frame_count += 1
        if not success:
            break
    cap.release()
    print('视频总帧数为',frame_count)
    
    # cv2.namedWindow('Crack Detection and Measurement Video Processing')
    cap = cv2.VideoCapture(input_path)
    frame_size = (cap.get(cv2.CAP_PROP_FRAME_WIDTH), cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # fourcc = int(cap.get(cv2.CAP_PROP_FOURCC))
    # fourcc = cv2.VideoWriter_fourcc(*'XVID')
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = cap.get(cv2.CAP_PROP_FPS)

    out = cv2.VideoWriter(output_path, fourcc, fps, (int(frame_size[0]), int(frame_size[1])))
    
    # 进度条绑定视频总帧数
    with tqdm(total=frame_count-1) as pbar:
        try:
            while(cap.isOpened()):
                success, frame = cap.read()
                if not success:
                    break

                # 处理帧
                # frame_path = './temp_frame.png'
                # cv2.imwrite(frame_path, frame)
                try:
                    frame = process_frame(frame)
                except:
                    print('error')
                    pass
                
                if success == True:
                    # cv2.imshow('Video Processing', frame)
                    out.write(frame)

                    # 进度条更新一帧
                    pbar.update(1)

                # if cv2.waitKey(1) & 0xFF == ord('q'):
                    # break
        except:
            print('中途中断')
            pass

    cv2.destroyAllWindows()
    out.release()
    cap.release()
    print('视频已保存', output_path)

# %% [markdown]
# ## 视频预测

# %%
generate_video(input_path='videos/mother_wx.mp4')
# Out:
# 视频开始处理 videos/mother_wx.mp4
# 视频总帧数为 157
#   0%|          | 0/156 [00:00<?, ?it/s]
# 0: 768x1280 3 persons, 97.8ms
# Speed: 0.7ms preprocess, 97.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#   1%|          | 1/156 [00:07<19:43,  7.64s/it]
# 0: 768x1280 3 persons, 96.5ms
# Speed: 0.6ms preprocess, 96.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#   1%|▏         | 2/156 [00:07<08:14,  3.21s/it]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   2%|▏         | 3/156 [00:07<04:34,  1.80s/it]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   3%|▎         | 4/156 [00:07<02:51,  1.13s/it]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#   3%|▎         | 5/156 [00:08<01:55,  1.31it/s]
# 0: 768x1280 3 persons, 96.6ms
# Speed: 0.6ms preprocess, 96.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#   4%|▍         | 6/156 [00:08<01:21,  1.84it/s]
# 0: 768x1280 3 persons, 96.6ms
# Speed: 0.6ms preprocess, 96.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#   4%|▍         | 7/156 [00:08<01:00,  2.48it/s]
# 0: 768x1280 3 persons, 96.6ms
# Speed: 0.6ms preprocess, 96.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   5%|▌         | 8/156 [00:08<00:46,  3.22it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   6%|▌         | 9/156 [00:08<00:36,  4.02it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   6%|▋         | 10/156 [00:08<00:30,  4.85it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   7%|▋         | 11/156 [00:08<00:25,  5.64it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#   8%|▊         | 12/156 [00:08<00:22,  6.35it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#   8%|▊         | 13/156 [00:08<00:20,  6.96it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#   9%|▉         | 14/156 [00:09<00:19,  7.46it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  10%|▉         | 15/156 [00:09<00:17,  7.86it/s]
# 0: 768x1280 3 persons, 96.6ms
# Speed: 0.6ms preprocess, 96.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  10%|█         | 16/156 [00:09<00:17,  8.16it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  11%|█         | 17/156 [00:09<00:16,  8.38it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  12%|█▏        | 18/156 [00:09<00:16,  8.54it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  12%|█▏        | 19/156 [00:09<00:15,  8.65it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  13%|█▎        | 20/156 [00:09<00:15,  8.73it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  13%|█▎        | 21/156 [00:09<00:15,  8.78it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  14%|█▍        | 22/156 [00:09<00:15,  8.81it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  15%|█▍        | 23/156 [00:10<00:15,  8.83it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  15%|█▌        | 24/156 [00:10<00:14,  8.85it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  16%|█▌        | 25/156 [00:10<00:14,  8.84it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  17%|█▋        | 26/156 [00:10<00:14,  8.84it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  17%|█▋        | 27/156 [00:10<00:14,  8.87it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  18%|█▊        | 28/156 [00:10<00:14,  8.87it/s]
# 0: 768x1280 3 persons, 96.6ms
# Speed: 0.6ms preprocess, 96.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  19%|█▊        | 29/156 [00:10<00:14,  8.89it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  19%|█▉        | 30/156 [00:10<00:14,  8.89it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  20%|█▉        | 31/156 [00:11<00:14,  8.89it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  21%|██        | 32/156 [00:11<00:13,  8.90it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  21%|██        | 33/156 [00:11<00:13,  8.89it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  22%|██▏       | 34/156 [00:11<00:13,  8.89it/s]
# 0: 768x1280 3 persons, 96.6ms
# Speed: 0.6ms preprocess, 96.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  22%|██▏       | 35/156 [00:11<00:13,  8.88it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  23%|██▎       | 36/156 [00:11<00:13,  8.90it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  24%|██▎       | 37/156 [00:11<00:13,  8.91it/s]
# 0: 768x1280 3 persons, 96.5ms
# Speed: 0.6ms preprocess, 96.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  24%|██▍       | 38/156 [00:11<00:13,  8.89it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  25%|██▌       | 39/156 [00:11<00:13,  8.88it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  26%|██▌       | 40/156 [00:12<00:13,  8.88it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  26%|██▋       | 41/156 [00:12<00:12,  8.87it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  27%|██▋       | 42/156 [00:12<00:12,  8.86it/s]
# 0: 768x1280 3 persons, 96.7ms
# Speed: 0.6ms preprocess, 96.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  28%|██▊       | 43/156 [00:12<00:12,  8.86it/s]
# 0: 768x1280 3 persons, 96.8ms
# Speed: 0.6ms preprocess, 96.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  28%|██▊       | 44/156 [00:12<00:12,  8.84it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  29%|██▉       | 45/156 [00:12<00:12,  8.83it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  29%|██▉       | 46/156 [00:12<00:12,  8.83it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  30%|███       | 47/156 [00:12<00:12,  8.82it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  31%|███       | 48/156 [00:12<00:12,  8.81it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  31%|███▏      | 49/156 [00:13<00:12,  8.81it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  32%|███▏      | 50/156 [00:13<00:12,  8.81it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  33%|███▎      | 51/156 [00:13<00:11,  8.82it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  33%|███▎      | 52/156 [00:13<00:11,  8.82it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  34%|███▍      | 53/156 [00:13<00:11,  8.83it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  35%|███▍      | 54/156 [00:13<00:11,  8.83it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  35%|███▌      | 55/156 [00:13<00:11,  8.82it/s]
# 0: 768x1280 3 persons, 97.1ms
# Speed: 0.6ms preprocess, 97.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  36%|███▌      | 56/156 [00:13<00:11,  8.81it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  37%|███▋      | 57/156 [00:13<00:11,  8.81it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  37%|███▋      | 58/156 [00:14<00:11,  8.80it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  38%|███▊      | 59/156 [00:14<00:11,  8.80it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  38%|███▊      | 60/156 [00:14<00:10,  8.80it/s]
# 0: 768x1280 4 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  39%|███▉      | 61/156 [00:14<00:10,  8.80it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  40%|███▉      | 62/156 [00:14<00:10,  8.81it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  40%|████      | 63/156 [00:14<00:10,  8.80it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  41%|████      | 64/156 [00:14<00:10,  8.79it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  42%|████▏     | 65/156 [00:14<00:10,  8.79it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  42%|████▏     | 66/156 [00:14<00:10,  8.80it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  43%|████▎     | 67/156 [00:15<00:10,  8.80it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  44%|████▎     | 68/156 [00:15<00:09,  8.80it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  44%|████▍     | 69/156 [00:15<00:09,  8.80it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#  45%|████▍     | 70/156 [00:15<00:09,  8.79it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  46%|████▌     | 71/156 [00:15<00:09,  8.80it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  46%|████▌     | 72/156 [00:15<00:09,  8.77it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  47%|████▋     | 73/156 [00:15<00:09,  8.78it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  47%|████▋     | 74/156 [00:15<00:09,  8.80it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  48%|████▊     | 75/156 [00:15<00:09,  8.80it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  49%|████▊     | 76/156 [00:16<00:09,  8.77it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  49%|████▉     | 77/156 [00:16<00:08,  8.78it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  50%|█████     | 78/156 [00:16<00:08,  8.76it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  51%|█████     | 79/156 [00:16<00:08,  8.76it/s]
# 0: 768x1280 4 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  51%|█████▏    | 80/156 [00:16<00:08,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  52%|█████▏    | 81/156 [00:16<00:08,  8.76it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  53%|█████▎    | 82/156 [00:16<00:08,  8.73it/s]
# 0: 768x1280 3 persons, 97.1ms
# Speed: 0.6ms preprocess, 97.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  53%|█████▎    | 83/156 [00:16<00:08,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  54%|█████▍    | 84/156 [00:17<00:08,  8.74it/s]
# 0: 768x1280 3 persons, 97.5ms
# Speed: 0.6ms preprocess, 97.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  54%|█████▍    | 85/156 [00:17<00:08,  8.74it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  55%|█████▌    | 86/156 [00:17<00:08,  8.72it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  56%|█████▌    | 87/156 [00:17<00:07,  8.72it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  56%|█████▋    | 88/156 [00:17<00:07,  8.72it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  57%|█████▋    | 89/156 [00:17<00:07,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  58%|█████▊    | 90/156 [00:17<00:07,  8.65it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  58%|█████▊    | 91/156 [00:17<00:07,  8.67it/s]
# 0: 768x1280 3 persons, 97.1ms
# Speed: 0.6ms preprocess, 97.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  59%|█████▉    | 92/156 [00:17<00:07,  8.66it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  60%|█████▉    | 93/156 [00:18<00:07,  8.67it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  60%|██████    | 94/156 [00:18<00:07,  8.69it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  61%|██████    | 95/156 [00:18<00:07,  8.69it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 2.6ms postprocess per image at shape (1, 3, 1280, 1280)
#  62%|██████▏   | 96/156 [00:18<00:06,  8.68it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  62%|██████▏   | 97/156 [00:18<00:06,  8.71it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  63%|██████▎   | 98/156 [00:18<00:06,  8.72it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  63%|██████▎   | 99/156 [00:18<00:06,  8.72it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  64%|██████▍   | 100/156 [00:18<00:06,  8.72it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  65%|██████▍   | 101/156 [00:18<00:06,  8.72it/s]
# 0: 768x1280 3 persons, 97.5ms
# Speed: 0.6ms preprocess, 97.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  65%|██████▌   | 102/156 [00:19<00:06,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  66%|██████▌   | 103/156 [00:19<00:06,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  67%|██████▋   | 104/156 [00:19<00:05,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  67%|██████▋   | 105/156 [00:19<00:05,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  68%|██████▊   | 106/156 [00:19<00:05,  8.73it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  69%|██████▊   | 107/156 [00:19<00:05,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#  69%|██████▉   | 108/156 [00:19<00:05,  8.69it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  70%|██████▉   | 109/156 [00:19<00:05,  8.70it/s]
# 0: 768x1280 3 persons, 97.2ms
# Speed: 0.6ms preprocess, 97.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#  71%|███████   | 110/156 [00:20<00:05,  8.71it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  71%|███████   | 111/156 [00:20<00:05,  8.71it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  72%|███████▏  | 112/156 [00:20<00:05,  8.71it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  72%|███████▏  | 113/156 [00:20<00:04,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  73%|███████▎  | 114/156 [00:20<00:04,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  74%|███████▎  | 115/156 [00:20<00:04,  8.74it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  74%|███████▍  | 116/156 [00:20<00:04,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  75%|███████▌  | 117/156 [00:20<00:04,  8.72it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  76%|███████▌  | 118/156 [00:20<00:04,  8.73it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  76%|███████▋  | 119/156 [00:21<00:04,  8.74it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  77%|███████▋  | 120/156 [00:21<00:04,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  78%|███████▊  | 121/156 [00:21<00:04,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  78%|███████▊  | 122/156 [00:21<00:03,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  79%|███████▉  | 123/156 [00:21<00:03,  8.75it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  79%|███████▉  | 124/156 [00:21<00:03,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  80%|████████  | 125/156 [00:21<00:03,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  81%|████████  | 126/156 [00:21<00:03,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  81%|████████▏ | 127/156 [00:21<00:03,  8.71it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#  82%|████████▏ | 128/156 [00:22<00:03,  8.71it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  83%|████████▎ | 129/156 [00:22<00:03,  8.72it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  83%|████████▎ | 130/156 [00:22<00:02,  8.73it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  84%|████████▍ | 131/156 [00:22<00:02,  8.74it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  85%|████████▍ | 132/156 [00:22<00:02,  8.73it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  85%|████████▌ | 133/156 [00:22<00:02,  8.74it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  86%|████████▌ | 134/156 [00:22<00:02,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  87%|████████▋ | 135/156 [00:22<00:02,  8.77it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  87%|████████▋ | 136/156 [00:22<00:02,  8.77it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  88%|████████▊ | 137/156 [00:23<00:02,  8.76it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  88%|████████▊ | 138/156 [00:23<00:02,  8.76it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  89%|████████▉ | 139/156 [00:23<00:01,  8.76it/s]
# 0: 768x1280 3 persons, 97.5ms
# Speed: 0.6ms preprocess, 97.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  90%|████████▉ | 140/156 [00:23<00:01,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  90%|█████████ | 141/156 [00:23<00:01,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  91%|█████████ | 142/156 [00:23<00:01,  8.75it/s]
# 0: 768x1280 3 persons, 97.5ms
# Speed: 0.6ms preprocess, 97.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  92%|█████████▏| 143/156 [00:23<00:01,  8.76it/s]
# 0: 768x1280 3 persons, 97.5ms
# Speed: 0.6ms preprocess, 97.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  92%|█████████▏| 144/156 [00:23<00:01,  8.76it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  93%|█████████▎| 145/156 [00:24<00:01,  8.76it/s]
# 0: 768x1280 3 persons, 97.5ms
# Speed: 0.6ms preprocess, 97.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  94%|█████████▎| 146/156 [00:24<00:01,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  94%|█████████▍| 147/156 [00:24<00:01,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  95%|█████████▍| 148/156 [00:24<00:00,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  96%|█████████▌| 149/156 [00:24<00:00,  8.75it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#  96%|█████████▌| 150/156 [00:24<00:00,  8.75it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  97%|█████████▋| 151/156 [00:24<00:00,  8.76it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  97%|█████████▋| 152/156 [00:24<00:00,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  98%|█████████▊| 153/156 [00:24<00:00,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#  99%|█████████▊| 154/156 [00:25<00:00,  8.74it/s]
# 0: 768x1280 3 persons, 97.4ms
# Speed: 0.6ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#  99%|█████████▉| 155/156 [00:25<00:00,  8.75it/s]
# 0: 768x1280 3 persons, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
# 100%|██████████| 156/156 [00:25<00:00,  6.17it/s]
# 视频已保存 out-mother_wx.mp4
