# %% [markdown]
# # 下载Triangle_251三角板关键点检测数据集
#
# 同济子豪兄 2023-4-26

# %% [markdown]
# ## 下载数据集

# %%
# 下载数据集至 datasets 目录
# !rm -rf datasets/Triangle_215_Keypoint_YOLO.zip datasets/Triangle_215_Keypoint_YOLO
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215_Keypoint_YOLO.zip -P datasets
# Out:
# --2023-04-26 22:12:39--  https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215_Keypoint_YOLO.zip
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 815291170 (778M) [application/zip]
# 正在保存至: “datasets/Triangle_215_Keypoint_YOLO.zip”
#
# Triangle_215_Keypoi 100%[===================>] 777.52M  43.9MB/s    用时 19s
#
# 2023-04-26 22:12:59 (41.7 MB/s) - 已保存 “datasets/Triangle_215_Keypoint_YOLO.zip” [815291170/815291170])

# %% [markdown]
# ## 解压数据集

# %%
# 解压
# !unzip datasets/Triangle_215_Keypoint_YOLO.zip -d datasets >> /dev/null

# 删除压缩包
# !rm -rf datasets/Triangle_215_Keypoint_YOLO.zip

# %% [markdown]
# ## 下载yaml配置文件

# %%
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215.yaml
# Out:
# --2023-04-27 13:14:36--  https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215.yaml
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 483 [text/yaml]
# 正在保存至: “Triangle_215.yaml”
#
# Triangle_215.yaml   100%[===================>]     483  --.-KB/s    用时 0s
#
# 2023-04-27 13:14:36 (52.3 MB/s) - 已保存 “Triangle_215.yaml” [483/483])

# %% [markdown]
# ## 删除系统自动生成的多余文件

# %% [markdown]
# ### 查看待删除的多余文件

# %%
# !find . -iname '__MACOSX'

# %%
# !find . -iname '.DS_Store'

# %%
# !find . -iname '.ipynb_checkpoints'
# Out:
# ./datasets/Triangle_215_Keypoint_YOLO/.ipynb_checkpoints
# ./.ipynb_checkpoints

# %% [markdown]
# ### 删除多余文件

# %%
# !for i in `find . -iname '__MACOSX'`; do rm -rf $i;done

# %%
# !for i in `find . -iname '.DS_Store'`; do rm -rf $i;done

# %%
# !for i in `find . -iname '.ipynb_checkpoints'`; do rm -rf $i;done

# %% [markdown]
# ### 验证多余文件已删除

# %%
# !find . -iname '__MACOSX'

# %%
# !find . -iname '.DS_Store'

# %%
# !find . -iname '.ipynb_checkpoints'

# %% [markdown]
# ## 查看目录结构

# %%
import seedir as sd
sd.seedir('.', style='emoji', depthlimit=1)
