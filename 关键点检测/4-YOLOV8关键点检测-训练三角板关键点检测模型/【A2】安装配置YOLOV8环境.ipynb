# %% [markdown]
# # 安装YOLOV8
#
# 同济子豪兄 2023-4-15
#
# 安装YOLOV8环境和所需的第三方工具包

# %% [markdown]
# ## 安装YOLOV8

# %%
# !pip install ultralytics --upgrade -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 验证安装成功

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.89 🚀 Python-3.7.10 torch-1.10.0+cu113 CUDA:0 (NVIDIA RTX A4000, 16117MiB)
# Setup complete ✅ (6 CPUs, 27.4 GB RAM, 19.9/406.9 GB disk)

# %% [markdown]
# ## 安装其它第三方工具包

# %%
# !pip install numpy opencv-python pillow pandas matplotlib seaborn tqdm wandb seedir emoji -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 登录训练可视化工具wandb
#
# 1.在命令行中运行wandb login
#
# 2.按提示复制粘贴API Key至命令行中
